# %%
import asyncio
import time
import random
import io
import os
import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(r"C:\Beamline Controls\11.0.1 Reflectometer\General Control\Remote Access\BCS API Clients\Python")
import BCSz

# %%
rsoxs = BCSz.BCSServer()

# %%
await rsoxs.connect(addr='localhost', port=5577)
# Out:
# Server Public Key b'NXd=+3(FkA]<s/HOu.V$0TeNF.%A[VVVTKVl7qpE'

# %%
ai_names = (await rsoxs.list_ais())['names']
dio_names = (await rsoxs.list_dios())['names']

# %%
print(await rsoxs.get_di(['Light Output']))
# Out:
# {'success': True, 'error description': 'no error', 'log?': True, 'chans': ['Light Output'], 'not_found': [], 'enabled': [True], 'data': [True], 'API_delta_t': 0.004796504974365234}

# %%
ai_names
# Out:
# ['EPU Polarization',
#  'Coolstage Temp C',
#  'CCD Temperature',
#  'Beam Current',
#  'TEY signal',
#  'Izero',
#  'Photodiode',
#  'AI 0',
#  'AI 3 Izero',
#  'AI 5',
#  'AI 6 BeamStop',
#  'AI 7',
#  'Temperature Controller',
#  'PZT Shutter',
#  'Pause Trigger',
#  'LV Memory',
#  'Deriv Photodiode',
#  'Time Stamp Error',
#  'Time Stamp Transmit Time',
#  'Time Stamp Server Time',
#  'Camera Temp Setpoint']

# %%
freerun = await rsoxs.get_freerun_array()

# %%
index = 7
yw = freerun['chans'][index]['data']
xw = freerun['chans'][index]['x_values']

# %%
plt.plot(xw, yw)
